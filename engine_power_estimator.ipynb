# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme()

data = pd.read_csv(r'data\dat.csv')

# %%
data.sample(10)
# Out:
#                                         name  year  selling_price  km_driven  \
# 3654          Tata Indica Vista Quadrajet LS  2012         300000     110000
# 371                      Chevrolet Spark 1.0  2009         125000      70000
# 1660         Mahindra KUV 100 mFALCON D75 K6  2016         430000      20000
# 301                      Mahindra Bolero SLX  2016         585000      51000
# 547                  Maruti Baleno Alpha 1.3  2016         770000      64672
# 2157  Ford EcoSport 1.5 Diesel Titanium BSIV  2019         950000      17000
# 2710                     Honda City 1.5 V MT  2009         250000      70000
# 3758                 Tata Sumo Gold EX BSIII  2015         399000      55250
# 4135               Mahindra Scorpio 2.6 CRDe  2006         125000      50000
# 2379                     Maruti Alto 800 LXI  2018         305000      35000
#
#         fuel       seller_type transmission         owner
# 3654  Diesel        Individual       Manual   First Owner
# ...
